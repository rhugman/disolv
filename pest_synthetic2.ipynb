# %%
import numpy as np
import os
import pandas as pd
import matplotlib as mpl
mpl.rcParams['font.size'] = 10

import matplotlib.pyplot as plt

import pyemu
import shutil

# %%
def plot_conc(prof, meas, figsize=(5,5)):
    fig = plt.figure(figsize=figsize)
    import matplotlib.colors as mcolors
    colours = mcolors.TABLEAU_COLORS

    x = 0
    for col in prof.columns[1:]:
        plt.plot(prof[col], prof['Depth [L]'], label=col, )
            
        plt.scatter(meas.iloc[:,x+1], meas.iloc[:,x+0],  marker = 'o', alpha=0.5)
        x+=2

    plt.ylabel('Depth below ground (m)')
    plt.xlabel('Salinity ($kg/m^3)$')
    plt.legend()

    plt.gca().invert_yaxis()
    return

def ConvertFEC(InData, Temp=20):

    Concentrations = np.zeros(len(InData))
    for i in range(len(InData)):
        if InData[i] < 10000:
            FEC20 = InData[i]/(1 + 0.024 * (Temp - 20))
            Concentrations[i] = (1870 - np.sqrt(1870**2 - 160 * FEC20))/80
        else:
            FEC23 = InData[i]/(1 + 0.024 * (Temp - 23))/1000/1000 * 100
            Concentrations[i] = (5.9738E-7 * FEC23**6 - 3.5136E-5 *
            FEC23**5 + 7.823E-4 * FEC23**4 - 8.0334E-3 * FEC23**3 +
            4.0791E-2 * FEC23**2 + 3.4996E-2 * FEC23 + 3.6104E-2) * 58.44

    return Concentrations

# %%
# Construct the original model
org_model_ws =  os.path.join('calib', 'DD16')


if not os.path.exists(org_model_ws):
    os.makedirs(org_model_ws)

import disolv
convertFEC=False

disolv.run(org_model_ws, org_model_ws, calibrate=False, convertFEC=convertFEC,
           method='SLSQP')

####
prof = pd.read_csv(os.path.join(org_model_ws, 'profiles.csv'))
meas = pd.read_csv(os.path.join(org_model_ws, 'measuredprofiles.csv'))

plot_conc(prof, meas)
# Out:
# No automatic calibration
# Equation will be solved at times 0.0, 0.08, 0.12, 0.8, 1.92, 2.83
# 6 measured profiles have been found
# RMSE: 468.6943453562364

# %%
# edit model parmaeters
# bh geometry 
in_csv = pd.read_csv(os.path.join(org_model_ws, 'in.csv'), header=None)

# grid discretisation
grid_dis = 1
in_csv.loc[in_csv[0].str.contains('Spatial discretization of grid'), 1] = grid_dis
# ensure peclet >2
Dispersivity = grid_dis/2
in_csv.loc[in_csv[0].str.contains('Dispersivity'), 1] = Dispersivity

in_csv.to_csv(os.path.join(org_model_ws, 'in.csv'), index=False, header=None)

# rebuild flows
top = in_csv.loc[in_csv[0].str.contains('Depth to groundwater level'), 1].values[0]
bot = in_csv.loc[in_csv[0].str.contains('Borehole depth'), 1].values[0]

flows = pd.read_csv(os.path.join(org_model_ws, 'flows.csv'))
new_flows = pd.DataFrame(columns= flows.columns)

import decimal

def drange(x, y, jump):
  while x < y:
    yield float(x)
    x += decimal.Decimal(jump)



new_flows['Depth [L]'] = list(drange(int(top), int(bot+grid_dis), str(grid_dis)))
new_flows.iloc[:, 1:] = 1, -1, 0, 0
new_flows.to_csv(os.path.join(org_model_ws, 'flows.csv'), index=False)


disolv.run(org_model_ws, org_model_ws, calibrate=False, convertFEC=convertFEC,
           method='SLSQP')
# Out:
# No automatic calibration
# Equation will be solved at times 0.0, 0.08, 0.12, 0.8, 1.92, 2.83
# 6 measured profiles have been found
# RMSE: 468.6943453562364

# %%
prof = pd.read_csv(os.path.join(org_model_ws, 'profiles.csv'))
meas = pd.read_csv(os.path.join(org_model_ws, 'measuredprofiles.csv'))

plot_conc(prof, meas)

# %%
# prepare calibration datase
# pest template folder
template_ws = os.path.join('calib',"pestpp_template")

# %%
# instantiate a PstFrom class
pf = pyemu.utils.PstFrom(original_d=org_model_ws, new_d=template_ws,
                 remove_existing=True, longnames=True)

# add imports
pf.extra_py_imports = ['disolv','pandas', 'os']

# add commands to model run
pf.mod_sys_cmds.append("python run_model.py")

# dont calibrate in/out flows directly
# calibrate a total flow and then have fractions; the fraction must add up to 1.0
# scale the fractions by the maximum fration value

# prepapre an input file for total flow; this file will be parameterized by PEST and used by run_model.py to update flows.csv
total_flow = 0.1
pd.DataFrame([total_flow], columns=['Flow [L^3 T^-1]']).to_csv(os.path.join(template_ws, 'total_flow.csv'))

# prepare a flow fraction csv file; this file will be parameterized by PEST and used by run_model.py to update flows.csv
flows = pd.read_csv(os.path.join(template_ws, 'flows.csv'))

for col in [1,2]:
    flows.iloc[:,col] = 0.5*flows.iloc[:,col]/abs(flows.iloc[:,col].max())

flows.to_csv(os.path.join(template_ws, 'flows_frac.csv'), index=False)

# flow parameters
pf.add_parameters(filenames='flows_frac.csv', mfile_skip=1,
                par_style='direct',
                par_type="grid",
                pargp=['in_flows', 'out_flows'], 
                upper_bound = 1e8, lower_bound=1e-8,
                index_cols=[0], use_cols=[1,2],
                transform='log',
                par_name_base=['in', 'out'])

# total flow parameter
pf.add_parameters(filenames='total_flow.csv', mfile_skip =1, 
                par_style='direct',
                par_type="constant",
                pargp='tot', 
                upper_bound = 1000, lower_bound=0,
                index_cols=[0], use_cols=[1],
                transform='log',
                par_name_base='tot')


# model parameters
pf.add_parameters(filenames='in.csv', mfile_skip=1,
                par_style='direct',
                par_type="grid",
                pargp='model', 
                upper_bound = 1e8, lower_bound=1e-12,
                index_cols=[0], use_cols=[1],
                transform='fixed')


# build the obs file
sim = pd.read_csv(os.path.join(org_model_ws, 'profiles.csv'))
meas = pd.read_csv(os.path.join(org_model_ws, 'measuredprofiles.csv'))

obs = sim.copy()
obs.iloc[:, 1:] = 1e30

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

x=0
for col in range(int(len(meas.columns)/2)):
    meas_col = col+x
    x+=1
    for row in range(len(meas.iloc[:,col])):
        meas_depth = meas.iloc[row, meas_col]
        sim_depth_idx = find_nearest(sim.iloc[:,0], meas_depth)

        obs.iloc[sim_depth_idx, col+1] = meas.iloc[row, meas_col+1]

obs.iloc[:, 0] = obs.iloc[:, 0].round(3)

obs.fillna(1e30, inplace=True)
obs.to_csv(os.path.join(template_ws, 'profiles.csv'), index=None)
obs.to_csv(os.path.join(template_ws, 'target-profiles.csv'), index=None)
# get obsg names fromtimes
obsgp = pd.read_csv(os.path.join(template_ws, 'output_times.csv')).iloc[:,0].values
obsgp = ['prof_'+str(i) for i in obsgp]
#use_cols = [i for i in range(1, 1 + len(obs.columns[1:]))]
pf.add_observations(filename='profiles.csv', ofile_skip=1, ofile_sep=None, rebuild_pst=False, zone_array=None, includes_header=False,
                    index_cols=[0],  obsgp=obsgp)

# add flows as observations/forecasts

pf.add_observations(filename='flows.csv', ofile_skip=1, ofile_sep=None, rebuild_pst=False, zone_array=None, includes_header=False,
                    index_cols=[0],use_cols=[1,2], obsgp=['flow_in', 'flow_out'], prefix='flow_' )


# add diference observations
# make difference observations
diff = obs.copy().replace(1e30, np.nan)
diff = diff.diff().replace(np.nan, 1e30)
diff.to_csv(os.path.join(template_ws, 'profiles-diff.csv'), index=None)

# make timedifference observations
tdiff = obs.copy()
tdiff.iloc[:, 1:] = obs.iloc[:, 1:].replace(1e30, np.nan).diff(axis=1).fillna(1e30)
tdiff.to_csv(os.path.join(template_ws, 'profiles-tdiff.csv'), index=None)

## add differnece obs
#pf.add_observations(filename='profiles-diff.csv', ofile_sep=None,ofile_skip=1, rebuild_pst=False, zone_array=None, includes_header=False,
#                    index_cols=[0], obsgp=[i+'_d' for i in obsgp], prefix='dif')
## add tdiffernece obs
#pf.add_observations(filename='profiles-tdiff.csv', ofile_sep=None, ofile_skip=1, rebuild_pst=False, zone_array=None, includes_header=False,
#                    index_cols=[0], obsgp=[i+'_td' for i in obsgp], prefix='tdif')


pst = pf.build_pst()

# tidy up parameters
par = pst.parameter_data

# set scale for out flows
par.loc[par['pargp'] == 'out_flows', 'scale'] = -1
par.loc[par['pargp'] == 'out_flows', 'parval1'] = abs(par.loc[par['pargp'] == 'out_flows', 'parval1'])
# correct parchglim
par.loc[par['partrans'] != 'none', 'parchglim'] = 'relative'

# add dispersivity and diffusion parameters
par.loc[par['parnme'].str.contains('Dispersivity') , ['partrans','parlbnd','parubnd', 'pargp']] = 'log', 1e-3, 10, 'disp'
par.loc[par['parnme'].str.contains('Diffusioncoefficient') , ['partrans','parlbnd','parubnd', 'pargp']] = 'log', 1e-12, 1e-6, 'diff'

# tidy up observations
obs = pst.observation_data
obs.loc[obs['obsval']==1e30, 'weight'] = 0
obs.loc[obs['obgnme']=='flow_in', 'weight'] = 0
obs.loc[obs['obgnme']=='flow_out', 'weight'] = 0

# blanace observation groups
# run once
pst.control_data.noptmax = 0
pst.write(os.path.join(pf.new_d, "disolv.pst"))
pyemu.os_utils.run('pestpp-glm disolv.pst', cwd=pf.new_d)
# weight for 100 each
balanced_groups = {grp:100 for grp in pst.nnz_obs_groups}
#adjust the weights
# reload pst file
pst = pyemu.Pst(os.path.join(pf.new_d, "disolv.pst"))
pst.adjust_weights(obsgrp_dict=balanced_groups)

# add prior information
# set prior info
"""priorinf = pst.prior_information
for pargp in ['in_flows', 'out_flows']:
        par_list = par.loc[par['pargp']==pargp, 'parnme']
        for i in range(len(par_list)):
                par1 = par_list[i]
                par2 = par_list[i-1]
                pst.add_pi_equation([par1, par2], pilbl=None, rhs=0.0, weight=1.0, obs_group='reg_'+pargp, coef_dict={par1:1, par2:-1})

pst.prior_information['equation'][-1]"""

# re-write
pst.control_data.relparmax = 30
pst.control_data.facparmax = 30
pst.control_data.rlambda1 = 10
pst.control_data.phiredlam = 0.03
pst.control_data.numlam = 10

# set noptmax
pst.control_data.noptmax = 50



pg = pst.parameter_groups
pg.loc[pg['pargpnme'].isin(['out_flows', 'in_flows']), ['inctyp', 'derinc','derinclb' ]] = 'relative', 0.01, 0.1


# write the updated pest control file
pst.write(os.path.join(pf.new_d, "disolv.pst"))
# Out:
# 2021-08-06 10:48:01.722052 starting: opening PstFrom.log for logging
# 2021-08-06 10:48:01.722052 starting PstFrom process
# 2021-08-06 10:48:01.722052 starting: setting up dirs
# 2021-08-06 10:48:01.723050 starting: removing existing new_d 'calib\pestpp_template'
# 2021-08-06 10:48:01.731029 finished: removing existing new_d 'calib\pestpp_template' took: 0:00:00.007979
# 2021-08-06 10:48:01.731029 starting: copying original_d 'calib\DD16' to new_d 'calib\pestpp_template'
# 2021-08-06 10:48:01.738039 finished: copying original_d 'calib\DD16' to new_d 'calib\pestpp_template' took: 0:00:00.007010
# 2021-08-06 10:48:01.739037 finished: setting up dirs took: 0:00:00.016985
# 2021-08-06 10:48:01.750009 starting: adding grid type direct style parameters for file(s) ['flows_frac.csv']
# 2021-08-06 10:48:01.750009 starting: loading list calib\pestpp_template\flows_frac.csv
# 2021-08-06 10:48:01.751004 starting: reading list calib\pestpp_template\flows_frac.csv
# 2021-08-06 10:48:01.752002 finished: reading list calib\pestpp_template\flows_frac.csv took: 0:00:00.000998
# 2021-08-06 10:48:01.752002 loaded list 'calib\pestpp_template\flows_frac.csv' of shape (60, 5)
# 2021-08-06 10:48:01.753996 finished: loading list calib\pestpp_template\flows_frac.csv took: 0:00:00.003987
# 2021-08-06 10:48:01.753996 starting: writing list-based template file 'calib\pestpp_template\flows_frac.csv.tpl'
# 2021-08-06 10:48:01.770951 finished: writing list-based template file 'calib\pestpp_template\flows_frac.csv.tpl' took: 0:00:00.016955
# 2021-08-06 10:48:01.775910 finished: adding grid type direct style parameters for file(s) ['flows_frac.csv'] took: 0:00:00.025901
# 2021-08-06 10:48:01.776937 starting: adding constant type direct style parameters for file(s) ['total_flow.csv']
# 2021-08-06 10:48:01.776937 starting: loading list calib\pestpp_template\total_flow.csv
# 2021-08-06 10:48:01.776937 starting: reading list calib\pestpp_template\total_flow.csv
# 2021-08-06 10:48:01.777932 finished: reading list calib\pestpp_template\total_flow.csv took: 0:00:00.000995
# 2021-08-06 10:48:01.778930 loaded list 'calib\pestpp_template\total_flow.csv' of shape (1, 2)
# 2021-08-06 10:48:01.778930 finished: loading list calib\pestpp_template\total_flow.csv took: 0:00:00.001993
# 2021-08-06 10:48:01.778930 starting: writing list-based template file 'calib\pestpp_template\total_flow.csv.tpl'
# 2021-08-06 10:48:01.788903 finished: writing list-based template file 'calib\pestpp_template\total_flow.csv.tpl' took: 0:00:00.009973
# 2021-08-06 10:48:01.793890 finished: adding constant type direct style parameters for file(s) ['total_flow.csv'] took: 0:00:00.016953
# 2021-08-06 10:48:01.793890 starting: adding grid type direct style parameters for file(s) ['in.csv']
# 2021-08-06 10:48:01.793890 starting: loading list calib\pestpp_template\in.csv
# 2021-08-06 10:48:01.793890 starting: reading list calib\pestpp_template\in.csv
# 2021-08-06 10:48:01.795895 finished: reading list calib\pestpp_template\in.csv took: 0:00:00.002005
# 2021-08-06 10:48:01.795895 loaded list 'calib\pestpp_template\in.csv' of shape (11, 2)
# 2021-08-06 10:48:01.796903 finished: loading list calib\pestpp_template\in.csv took: 0:00:00.003013
# 2021-08-06 10:48:01.796903 starting: writing list-based template file 'calib\pestpp_template\in.csv.tpl'
# 2021-08-06 10:48:01.807852 finished: writing list-based template file 'calib\pestpp_template\in.csv.tpl' took: 0:00:00.010949
# 2021-08-06 10:48:01.812846 finished: adding grid type direct style parameters for file(s) ['in.csv'] took: 0:00:00.018956
# D:\github\pyemu\pyemu\utils\pst_from.py:3007: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_ti.loc[:, "idx_strs"] = df_ti.idx_strs.str.replace("|", ":")
# 2021-08-06 10:48:02.015319 starting: adding observations from output file profiles.csv
# 2021-08-06 10:48:02.016311 starting: adding observations from tabular output file '['profiles.csv']'
# 2021-08-06 10:48:02.016311 starting: reading list calib\pestpp_template\profiles.csv
# 2021-08-06 10:48:02.017291 finished: reading list calib\pestpp_template\profiles.csv took: 0:00:00.000980
# 2021-08-06 10:48:02.018307 starting: building insfile for tabular output file profiles.csv
# 2021-08-06 10:48:02.024272 finished: building insfile for tabular output file profiles.csv took: 0:00:00.005965
# 2021-08-06 10:48:02.024272 starting: adding observation from instruction file 'calib\pestpp_template\profiles.csv.ins'
# 2021-08-06 10:48:02.033220 finished: adding observation from instruction file 'calib\pestpp_template\profiles.csv.ins' took: 0:00:00.008948
# 2021-08-06 10:48:02.035214 finished: adding observations from tabular output file '['profiles.csv']' took: 0:00:00.018903
# 2021-08-06 10:48:02.035214 starting: adding observations from output file flows.csv
# 2021-08-06 10:48:02.035214 starting: adding observations from tabular output file '['flows.csv']'
# 2021-08-06 10:48:02.035214 starting: reading list calib\pestpp_template\flows.csv
# 2021-08-06 10:48:02.037208 finished: reading list calib\pestpp_template\flows.csv took: 0:00:00.001994
# 2021-08-06 10:48:02.037208 starting: building insfile for tabular output file flows.csv
# 2021-08-06 10:48:02.044191 finished: building insfile for tabular output file flows.csv took: 0:00:00.006983
# 2021-08-06 10:48:02.045188 starting: adding observation from instruction file 'calib\pestpp_template\flows.csv.ins'
# 2021-08-06 10:48:02.052168 finished: adding observation from instruction file 'calib\pestpp_template\flows.csv.ins' took: 0:00:00.006980
# 2021-08-06 10:48:02.053165 finished: adding observations from tabular output file '['flows.csv']' took: 0:00:00.017951
# noptmax:0, npar_adj:121, nnz_obs:480
# 2021-08-06 10:48:02.139963 forward_run line:pyemu.os_utils.run(r'python run_model.py')
#
# noptmax:0, npar_adj:123, nnz_obs:349
# noptmax:50, npar_adj:123, nnz_obs:349

# %%
# run pest glm
#pyemu.helpers.run(f"pestpp-glm disolv.pst",cwd=pf.new_d)

num_workers = 10

m_d = os.path.join('calib', 'master')
# worker directory
worker_root = os.path.abspath(os.path.join('r:','Temp','.'))
#worker_root = os.path.join('calib', 'workers')

# %%
pyemu.os_utils.start_workers(template_ws,"pestpp-glm", "disolv.pst",num_workers=num_workers,master_dir=m_d, worker_root=worker_root, cleanup=True)

# %%
# run the model once to update parameters; parrep does not like these files for some reason
calib_par = pd.read_csv(os.path.join(m_d, 'disolv.par'), delim_whitespace=True, skiprows=1, header=None, names=['parnme', 'parval1', 'scale','offset'] )

par = pst.parameter_data
par.loc[:, 'parval1'] = calib_par['parval1'].values
par.head()
# Out:
#                                                                     parnme  \
# parnme
# in_inst:0_usecol:1_direct_idx0:29.0    in_inst:0_usecol:1_direct_idx0:29.0
# out_inst:0_usecol:2_direct_idx0:29.0  out_inst:0_usecol:2_direct_idx0:29.0
# in_inst:0_usecol:1_direct_idx0:30.0    in_inst:0_usecol:1_direct_idx0:30.0
# out_inst:0_usecol:2_direct_idx0:30.0  out_inst:0_usecol:2_direct_idx0:30.0
# in_inst:0_usecol:1_direct_idx0:31.0    in_inst:0_usecol:1_direct_idx0:31.0
#
#                                      partrans parchglim    parval1  \
# parnme
# in_inst:0_usecol:1_direct_idx0:29.0       log  relative   0.651444
# out_inst:0_usecol:2_direct_idx0:29.0      log  relative   0.237885
# in_inst:0_usecol:1_direct_idx0:30.0       log  relative  13.454484
# out_inst:0_usecol:2_direct_idx0:30.0      log  relative   0.116918
# in_inst:0_usecol:1_direct_idx0:31.0       log  relative   0.339146
#
#                                            parlbnd      parubnd      pargp  \
# parnme
# in_inst:0_usecol:1_direct_idx0:29.0   1.000000e-08  100000000.0   in_flows
# out_inst:0_usecol:2_direct_idx0:29.0  1.000000e-08  100000000.0  out_flows
# in_inst:0_usecol:1_direct_idx0:30.0   1.000000e-08  100000000.0   in_flows
# out_inst:0_usecol:2_direct_idx0:30.0  1.000000e-08  100000000.0  out_flows
# in_inst:0_usecol:1_direct_idx0:31.0   1.000000e-08  100000000.0   in_flows
#
#                                       scale  offset dercom  extra inst usecol  \
# parnme
# in_inst:0_usecol:1_direct_idx0:29.0     1.0     0.0      1    NaN    0      1
# out_inst:0_usecol:2_direct_idx0:29.0   -1.0     0.0      1    NaN    0      2
# in_inst:0_usecol:1_direct_idx0:30.0     1.0     0.0      1    NaN    0      1
# out_inst:0_usecol:2_direct_idx0:30.0   -1.0     0.0      1    NaN    0      2
# in_inst:0_usecol:1_direct_idx0:31.0     1.0     0.0      1    NaN    0      1
#
#                                       idx0
# parnme
# in_inst:0_usecol:1_direct_idx0:29.0   29.0
# out_inst:0_usecol:2_direct_idx0:29.0  29.0
# in_inst:0_usecol:1_direct_idx0:30.0   30.0
# out_inst:0_usecol:2_direct_idx0:30.0  30.0
# in_inst:0_usecol:1_direct_idx0:31.0   31.0

# %%
# set noptmax
pst.control_data.noptmax = 0
pst.write(os.path.join(m_d, "disolv_calib.pst"))
pyemu.os_utils.run('pestpp-glm disolv_calib.pst', cwd=m_d)
# Out:
# noptmax:0, npar_adj:123, nnz_obs:349

# %%
prof = pd.read_csv(os.path.join(m_d, 'profiles.csv'))
meas = pd.read_csv(os.path.join(m_d, 'measuredprofiles.csv'))

plot_conc(prof, meas)

# %%
if convertFEC==True:
    for col in meas.columns[1::2]:
        meas[col] = ConvertFEC(meas[col])

# %%
disolv.run(m_d, m_d, calibrate=False, convertFEC=convertFEC,
           method='SLSQP')

prof = pd.read_csv(os.path.join(m_d, 'profiles.csv'))
meas = pd.read_csv(os.path.join(m_d, 'measuredprofiles.csv'))

plot_conc(prof, meas)
# Out:
# No automatic calibration
# Equation will be solved at times 0.0, 0.08, 0.12, 0.8, 1.92, 2.83
# 6 measured profiles have been found
# RMSE: 37.62701106382063

# %%
prof = pd.read_csv(os.path.join(m_d, 'profiles.csv'))
meas = pd.read_csv(os.path.join(m_d, 'measuredprofiles.csv'))

plot_conc(prof, meas, (7,7))

# %%
flows = pd.read_csv(os.path.join(m_d, 'flows.csv'))

df = flows.iloc[:,0:3]
df.iloc[:,2] *= -1

df.head()

plt.barh(df['Depth [L]'], df['In_Flow [L^3 T^-1]'],  color='tab:blue', height=0.5, alpha=1, zorder=3)
plt.barh(df['Depth [L]'], df['Out_Flow [L^3 T^-1]'],  color='tab:orange', height=0.5, alpha=1, zorder=3)

plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
